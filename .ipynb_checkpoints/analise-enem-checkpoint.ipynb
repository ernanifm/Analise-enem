# %% [markdown]
# # Análise dos microdados do Enem 2021

# %%
# Importando bibliotecas

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sn

# %%
import matplotlib

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ## 1. Leitura do arquivo "MICRODADOS_ENEM_2021.csv" para um dataframe
# Vamos carregar o arquivo dos microdados e fazer uma exploração inicial do dataframe

# %%
# A biblioteca Pandas, por padrão, lê o encoding como utf-8, no entanto, quando não reconhece algum caracter ele retorna um erro.
# Pesquisando, podemos achar alguns encodings que podem nos servir, no caso, ISO-8859-1. Outro encoding que poderia ser usado: latin1

# %%
microdados_enem = pd.read_csv('C:/Users/ernan/Documents/Git/DADOS/MICRODADOS_ENEM_2021.csv', encoding= 'ISO-8859-1', sep = ';')

# %%
microdados_enem.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210053865474    2021                5       F                1
# 1  210052384164    2021               12       M                1
# 2  210052589243    2021               13       F                3
# 3  210052128335    2021                3       M                1
# 4  210051353021    2021                2       F                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            1                 1                1                3          1
# 1            1                 1                1               11          1
# 2            1                 1                1               15          1
# 3            3                 1                2                0          2
# 4            3                 1                2                0          2
#
#    ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  Q025
# 0  ...     A     A     A    B     A    A     B     A     B     B
# 1  ...     A     A     A    B     A    A     C     A     A     A
# 2  ...     B     A     A    B     A    A     C     B     B     B
# 3  ...     A     A     A    B     A    A     B     A     B     B
# 4  ...     B     A     A    B     A    B     E     A     B     B
#
# [5 rows x 76 columns]

# %%
microdados_enem.tail()
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 3389827  210053249138    2021                7       F                1
# 3389828  210053776013    2021                7       F                1
# 3389829  210052441508    2021               13       F                1
# 3389830  210051139675    2021                7       F                1
# 3389831  210052410399    2021               12       F                2
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# 3389827            3                 1                1                0
# 3389828            1                 1                1                5
# 3389829            3                 1                1               15
# 3389830            1                 1                1                4
# 3389831            3                 1                1               15
#
#          TP_ESCOLA  ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  \
# 3389827          1  ...     A     A     A    B     A    A     B     A     A
# 3389828          1  ...     B     A     B    C     A    A     E     B     B
# 3389829          1  ...     B     A     A    A     A    A     B     A     B
# 3389830          1  ...     B     A     B    B     A    B     E     A     C
# 3389831          1  ...   NaN   NaN   NaN  NaN   NaN  NaN   NaN   NaN   NaN
#
#          Q025
# 3389827     B
# 3389828     B
# 3389829     B
# 3389830     B
# 3389831   NaN
#
# [5 rows x 76 columns]

# %%
len(microdados_enem.NU_INSCRICAO)
# Out:
# 3389832

# %%
microdados_enem.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
#        'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
#        'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
#        'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
#        'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
#        'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
#        'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
#        'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
#        'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
#        'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006',
#        'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014',
#        'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022',
#        'Q023', 'Q024', 'Q025'], dtype=object)

# %%
microdados_enem.dtypes
# Out:
# NU_INSCRICAO        int64
# NU_ANO              int64
# TP_FAIXA_ETARIA     int64
# TP_SEXO            object
# TP_ESTADO_CIVIL     int64
#                     ...
# Q021               object
# Q022               object
# Q023               object
# Q024               object
# Q025               object
# Length: 76, dtype: object

# %%
microdados_enem.describe()
# Out:
#        NU_INSCRICAO     NU_ANO  TP_FAIXA_ETARIA  TP_ESTADO_CIVIL  \
# count  3.389832e+06  3389832.0     3.389832e+06     3.389832e+06
# mean   2.100527e+11     2021.0     5.306013e+00     1.052073e+00
# std    9.962403e+05        0.0     3.902871e+00     4.129414e-01
# min    2.100510e+11     2021.0     1.000000e+00     0.000000e+00
# 25%    2.100519e+11     2021.0     2.000000e+00     1.000000e+00
# 50%    2.100527e+11     2021.0     4.000000e+00     1.000000e+00
# 75%    2.100536e+11     2021.0     7.000000e+00     1.000000e+00
# max    2.100545e+11     2021.0     2.000000e+01     4.000000e+00
#
#         TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# count  3.389832e+06      3.389832e+06     3.389832e+06     3.389832e+06
# mean   2.043491e+00      1.027106e+00     1.608430e+00     2.581980e+00
# std    1.022561e+00      2.049293e-01     7.198306e-01     4.278731e+00
# min    0.000000e+00      0.000000e+00     1.000000e+00     0.000000e+00
# 25%    1.000000e+00      1.000000e+00     1.000000e+00     0.000000e+00
# 50%    2.000000e+00      1.000000e+00     1.000000e+00     0.000000e+00
# 75%    3.000000e+00      1.000000e+00     2.000000e+00     3.000000e+00
# max    6.000000e+00      4.000000e+00     4.000000e+00     1.500000e+01
#
#           TP_ESCOLA     TP_ENSINO  ...    NU_NOTA_MT     TP_LINGUA  \
# count  3.389832e+06  1.096828e+06  ...  2.245844e+06  3.389832e+06
# mean   1.396214e+00  1.006295e+00  ...  5.350802e+02  4.704640e-01
# std    5.938455e-01  7.909361e-02  ...  1.106267e+02  4.991269e-01
# min    1.000000e+00  1.000000e+00  ...  0.000000e+00  0.000000e+00
# 25%    1.000000e+00  1.000000e+00  ...  4.447000e+02  0.000000e+00
# 50%    1.000000e+00  1.000000e+00  ...  5.154000e+02  0.000000e+00
# 75%    2.000000e+00  1.000000e+00  ...  6.139000e+02  1.000000e+00
# max    3.000000e+00  2.000000e+00  ...  9.531000e+02  1.000000e+00
#
#        TP_STATUS_REDACAO  NU_NOTA_COMP1  NU_NOTA_COMP2  NU_NOTA_COMP3  \
# count       2.378379e+06   2.378379e+06   2.378379e+06   2.378379e+06
# mean        1.140684e+00   1.192657e+02   1.380269e+02   1.153117e+02
# std         7.910804e-01   3.391962e+01   4.563224e+01   3.634138e+01
# min         1.000000e+00   0.000000e+00   0.000000e+00   0.000000e+00
# 25%         1.000000e+00   1.000000e+02   1.200000e+02   1.000000e+02
# 50%         1.000000e+00   1.200000e+02   1.200000e+02   1.200000e+02
# 75%         1.000000e+00   1.400000e+02   1.800000e+02   1.400000e+02
# max         9.000000e+00   2.000000e+02   2.000000e+02   2.000000e+02
#
#        NU_NOTA_COMP4  NU_NOTA_COMP5  NU_NOTA_REDACAO          Q005
# count   2.378379e+06   2.378379e+06     2.378379e+06  3.389830e+06
# mean    1.281853e+02   1.127109e+02     6.135005e+02  3.739557e+00
# std     3.883252e+01   6.005667e+01     1.907142e+02  1.378942e+00
# min     0.000000e+00   0.000000e+00     0.000000e+00  1.000000e+00
# 25%     1.200000e+02   8.000000e+01     5.200000e+02  3.000000e+00
# 50%     1.200000e+02   1.200000e+02     6.000000e+02  4.000000e+00
# 75%     1.600000e+02   1.600000e+02     7.400000e+02  4.000000e+00
# max     2.000000e+02   2.000000e+02     1.000000e+03  2.000000e+01
#
# [8 rows x 39 columns]

# %% [markdown]
# ## 2. Verificação de correlações entre notas
# Observando o dicionário de dados, selecionaremos algumas colunas que poderiam revelar possíveis correlações
# entre as notas dos candidatos. Além disso, criaremos uma nova coluna com a média das notas das áreas e da redação, excluindo
# os valores Nan, que provavelmente representam aqueles candidatos que faltaram a uma ou mais provas

# %%
colunas_selecionadas = ['NU_INSCRICAO','NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
       'NU_NOTA_MT', 'NU_NOTA_REDACAO']

# %%
microdados_selecionados = microdados_enem.filter(items=colunas_selecionadas)

# %%
microdados_selecionados.head()
# Out:
#    NU_INSCRICAO  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  \
# 0  210053865474         NaN       574.6       472.6         NaN
# 1  210052384164       505.9       551.8       498.3       461.5
# 2  210052589243         NaN         NaN         NaN         NaN
# 3  210052128335       580.7       678.9       638.9       659.5
# 4  210051353021       497.7       532.4       457.6       582.6
#
#    NU_NOTA_REDACAO
# 0            760.0
# 1            560.0
# 2              NaN
# 3            780.0
# 4            780.0

# %%
microdados_selecionados.isnull()
# Out:
#          NU_INSCRICAO  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  \
# 0               False        True       False       False        True
# 1               False       False       False       False       False
# 2               False        True        True        True        True
# 3               False       False       False       False       False
# 4               False       False       False       False       False
# ...               ...         ...         ...         ...         ...
# 3389827         False        True        True        True        True
# 3389828         False        True        True        True        True
# 3389829         False        True        True        True        True
# 3389830         False       False       False       False       False
# 3389831         False        True        True        True        True
#
#          NU_NOTA_REDACAO
# 0                  False
# 1                  False
# 2                   True
# 3                  False
# 4                  False
# ...                  ...
# 3389827             True
# 3389828             True
# 3389829             True
# 3389830            False
# 3389831             True
#
# [3389832 rows x 6 columns]

# %%
# criando uma coluna com a média das notas

# %%
microdados_selecionados['MEDIA'] = (microdados_selecionados['NU_NOTA_CN'] + microdados_selecionados['NU_NOTA_CH'] 
+ microdados_selecionados['NU_NOTA_MT'] + microdados_selecionados['NU_NOTA_REDACAO']+microdados_selecionados['NU_NOTA_LC'])/5

# %%
microdados_selecionados.head()
# Out:
#    NU_INSCRICAO  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  \
# 0  210053865474         NaN       574.6       472.6         NaN
# 1  210052384164       505.9       551.8       498.3       461.5
# 2  210052589243         NaN         NaN         NaN         NaN
# 3  210052128335       580.7       678.9       638.9       659.5
# 4  210051353021       497.7       532.4       457.6       582.6
#
#    NU_NOTA_REDACAO   MEDIA
# 0            760.0     NaN
# 1            560.0  515.50
# 2              NaN     NaN
# 3            780.0  667.60
# 4            780.0  570.06

# %%
microdados_selecionados['MEDIA'] = microdados_selecionados['MEDIA'].fillna(0)

# %%
microdados_selecionados.head()
# Out:
#    NU_INSCRICAO  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  \
# 0  210053865474         NaN       574.6       472.6         NaN
# 1  210052384164       505.9       551.8       498.3       461.5
# 2  210052589243         NaN         NaN         NaN         NaN
# 3  210052128335       580.7       678.9       638.9       659.5
# 4  210051353021       497.7       532.4       457.6       582.6
#
#    NU_NOTA_REDACAO   MEDIA
# 0            760.0    0.00
# 1            560.0  515.50
# 2              NaN    0.00
# 3            780.0  667.60
# 4            780.0  570.06

# %%
# Limpando NaN da coluna MEDIA

# %%
filtro = microdados_selecionados['MEDIA'] > 0

# %%
microdados_limpos = microdados_selecionados[filtro]

# %%
microdados_limpos.head()
# Out:
#    NU_INSCRICAO  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  \
# 1  210052384164       505.9       551.8       498.3       461.5
# 3  210052128335       580.7       678.9       638.9       659.5
# 4  210051353021       497.7       532.4       457.6       582.6
# 8  210053417016       487.4       476.5       450.7       493.4
# 9  210051128744       507.6       539.2       494.6       413.3
#
#    NU_NOTA_REDACAO   MEDIA
# 1            560.0  515.50
# 3            780.0  667.60
# 4            780.0  570.06
# 8            520.0  485.60
# 9            380.0  466.94

# %%
len(microdados_limpos)
# Out:
# 2238093

# %%
correlacao = microdados_limpos.corr()

# %%
correlacao
# Out:
#                  NU_INSCRICAO  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  \
# NU_INSCRICAO         1.000000    0.000518    0.000691    0.001689    0.001525
# NU_NOTA_CN           0.000518    1.000000    0.673103    0.661370    0.669637
# NU_NOTA_CH           0.000691    0.673103    1.000000    0.751756    0.623394
# NU_NOTA_LC           0.001689    0.661370    0.751756    1.000000    0.627878
# NU_NOTA_MT           0.001525    0.669637    0.623394    0.627878    1.000000
# NU_NOTA_REDACAO      0.000892    0.467237    0.481013    0.506921    0.485771
# MEDIA                0.001285    0.799663    0.819941    0.820556    0.813244
#
#                  NU_NOTA_REDACAO     MEDIA
# NU_INSCRICAO            0.000892  0.001285
# NU_NOTA_CN              0.467237  0.799663
# NU_NOTA_CH              0.481013  0.819941
# NU_NOTA_LC              0.506921  0.820556
# NU_NOTA_MT              0.485771  0.813244
# NU_NOTA_REDACAO         1.000000  0.810021
# MEDIA                   0.810021  1.000000

# %%
plot = sn.heatmap(correlacao, annot = True, fmt=".1f", linewidths=.6)
plot
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 3. Análise exploratória
#
# Vamos criar alguns dataframes reduzidos e criar alguns gráficos

# %%
# Analisando as variáveis

# %%
colunas_TP_SEXO = microdados_enem['TP_SEXO']

# %%
colunas_TP_SEXO.value_counts()
# Out:
# F    2090526
# M    1299306
# Name: TP_SEXO, dtype: int64

# %%
microdados_enem.loc[microdados_enem['TP_COR_RACA'] == 0, 'TP_COR_RACA'] = 'ND'

# %%
microdados_enem.loc[microdados_enem['TP_COR_RACA'] == 1, 'TP_COR_RACA'] = 'Branca'

# %%
microdados_enem.loc[microdados_enem['TP_COR_RACA'] == 2, 'TP_COR_RACA'] = 'Preta'

# %%
microdados_enem.loc[microdados_enem['TP_COR_RACA'] == 3, 'TP_COR_RACA'] = 'Parda'

# %%
microdados_enem.loc[microdados_enem['TP_COR_RACA'] == 4, 'TP_COR_RACA'] = 'Amarela'

# %%
microdados_enem.loc[microdados_enem['TP_COR_RACA'] == 5, 'TP_COR_RACA'] = 'Indígena'

# %%
microdados_enem.loc[microdados_enem['TP_COR_RACA'] == 6, 'TP_COR_RACA'] = 'ND'

# %%
microdados_enem['TP_COR_RACA'].value_counts()
# Out:
# Parda       1457454
# Branca      1362256
# Preta        411302
# ND            71154
# Amarela       68491
# Indígena      19175
# Name: TP_COR_RACA, dtype: int64

# %%
microdados_enem['TP_COR_RACA'].hist()
# Out:
# <AxesSubplot:>

# %%
microdados_enem.loc[microdados_enem['TP_DEPENDENCIA_ADM_ESC'] == 1, 'TP_DEPENDENCIA_ADM_ESC'] = 'Federal'

# %%
microdados_enem.loc[microdados_enem['TP_DEPENDENCIA_ADM_ESC'] == 2, 'TP_DEPENDENCIA_ADM_ESC'] = 'Estadual'

# %%
microdados_enem.loc[microdados_enem['TP_DEPENDENCIA_ADM_ESC'] == 3, 'TP_DEPENDENCIA_ADM_ESC'] = 'Municipal'

# %%
microdados_enem.loc[microdados_enem['TP_DEPENDENCIA_ADM_ESC'] == 4,'TP_DEPENDENCIA_ADM_ESC'] = 'Privada'

# %%
escolas = ['Estadual', 'Privada', 'Federal', 'Municipal'] 

plt.pie(microdados_enem['TP_DEPENDENCIA_ADM_ESC'].value_counts(), labels = escolas) 
plt.show()

# %%
microdados_enem['TP_DEPENDENCIA_ADM_ESC'].value_counts()
# Out:
# Estadual     548998
# Privada      210765
# Federal       46789
# Municipal      7254
# Name: TP_DEPENDENCIA_ADM_ESC, dtype: int64

# %%
colunas_selecionadas = ['NU_INSCRICAO', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_ESCOLA', 
                        'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC','Q006', 'Q007', 'Q024']
